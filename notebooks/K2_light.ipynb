# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# %%capture
# !pip install xgboost

# %%
pd.set_option("display.max_columns", None)
df = pd.read_csv('k2pandc_2025.10.03_17.22.31 (1).csv')
df = df[df["disposition"].isin(["CONFIRMED", "FALSE POSITIVE", "CANDIDATE"])]
df.head()
# Out:
#    loc_rowid            pl_name        hostname  default_flag disposition  \
# 0          1        BD+20 594 b       BD+20 594             0   CONFIRMED
# 1          2        BD+20 594 b       BD+20 594             0   CONFIRMED
# 2          3        BD+20 594 b       BD+20 594             1   CONFIRMED
# 3          4  EPIC 201111557.01  EPIC 201111557             1   CANDIDATE
# 4          5  EPIC 201111557.01  EPIC 201111557             0   CANDIDATE
#
#              disp_refname  sy_snum  sy_pnum discoverymethod  disc_year  \
# 0    Espinoza et al. 2016        1        1         Transit       2016
# 1    Espinoza et al. 2016        1        1         Transit       2016
# 2    Espinoza et al. 2016        1        1         Transit       2016
# 3  Livingston et al. 2018        1        0         Transit       2018
# 4  Livingston et al. 2018        1        0         Transit       2018
#
#   disc_facility              soltype  pl_controv_flag  \
# 0            K2  Published Confirmed                0
# 1            K2  Published Confirmed                0
# 2            K2  Published Confirmed                0
# 3            K2  Published Candidate                0
# 4            K2  Published Candidate                0
#
#                                           pl_refname  pl_orbper  \
# 0  <a refstr=MAYO_ET_AL__2018 href=https://ui.ads...  41.688644
# 1  <a refstr=ESPINOZA_ET_AL__2016 href=https://ui...  41.685500
# 2  <a refstr=STASSUN_ET_AL__2017 href=https://ui....  41.685500
# 3  <a refstr=LIVINGSTON_ET_AL__2018 href=https://...   2.301830
# 4  <a refstr=MAYO_ET_AL__2018 href=https://ui.ads...   2.302368
#
#    pl_orbpererr1  pl_orbpererr2  pl_orbperlim  pl_orbsmax  pl_orbsmaxerr1  \
# 0       0.003353      -0.003419           0.0         NaN             NaN
# 1       0.003000      -0.003100           0.0       0.241           0.019
# 2       0.003000      -0.003000           0.0         NaN             NaN
# 3       0.000280      -0.000300           0.0         NaN             NaN
# 4       0.000105      -0.000103           0.0         NaN             NaN
#
#    pl_orbsmaxerr2  pl_orbsmaxlim   pl_rade  pl_radeerr1  pl_radeerr2  \
# 0             NaN            NaN  2.355454     0.310000    -0.166773
# 1          -0.017            0.0  2.230000     0.140000    -0.110000
# 2             NaN            NaN  2.578070     0.112090    -0.112090
# 3             NaN            NaN  1.120000     0.110000    -0.080000
# 4             NaN            NaN  1.312588     0.524177    -0.120814
#
#    pl_radelim   pl_radj  pl_radjerr1  pl_radjerr2  pl_radjlim  pl_bmasse  \
# 0         0.0  0.210139     0.027656    -0.014878         0.0        NaN
# 1         0.0  0.198947     0.012490    -0.009814         0.0    16.3000
# 2         0.0  0.230000     0.010000    -0.010000         0.0    22.2481
# 3         0.0  0.099900     0.009800    -0.007000         0.0        NaN
# 4         0.0  0.120000     0.050000    -0.010000         0.0        NaN
#
#    pl_bmasseerr1  pl_bmasseerr2  pl_bmasselim  pl_bmassj  pl_bmassjerr1  \
# 0            NaN            NaN           NaN        NaN            NaN
# 1         6.0000        -6.1000           0.0   0.051285       0.018878
# 2         9.5349        -9.5349           0.0   0.070000       0.030000
# 3            NaN            NaN           NaN        NaN            NaN
# 4            NaN            NaN           NaN        NaN            NaN
#
#    pl_bmassjerr2  pl_bmassjlim pl_bmassprov  pl_orbeccen  pl_orbeccenerr1  \
# 0            NaN           NaN          NaN          NaN              NaN
# 1      -0.019193           0.0         Mass          0.0              NaN
# 2      -0.030000           0.0         Mass          0.0              NaN
# 3            NaN           NaN          NaN          NaN              NaN
# 4            NaN           NaN          NaN          NaN              NaN
#
#    pl_orbeccenerr2  pl_orbeccenlim  pl_insol  pl_insolerr1  pl_insolerr2  \
# 0              NaN             NaN       NaN           NaN           NaN
# 1              NaN             0.0       NaN           NaN           NaN
# 2              NaN             0.0       NaN           NaN           NaN
# 3              NaN             NaN       NaN           NaN           NaN
# 4              NaN             NaN       NaN           NaN           NaN
#
#    pl_insollim  pl_eqt  pl_eqterr1  pl_eqterr2  pl_eqtlim  ttv_flag  \
# 0          NaN     NaN         NaN         NaN        NaN         0
# 1          NaN   546.0        19.0       -18.0        0.0         0
# 2          NaN     NaN         NaN         NaN        NaN         0
# 3          NaN  1054.0        55.0       -55.0        0.0         0
# 4          NaN     NaN         NaN         NaN        NaN         0
#
#                                           st_refname st_spectype  st_teff  \
# 0  <a refstr=MAYO_ET_AL__2018 href=https://ui.ads...         NaN  5703.00
# 1  <a refstr=ESPINOZA_ET_AL__2016 href=https://ui...           G  5766.00
# 2  <a refstr=STASSUN_ET_AL__2017 href=https://ui....         NaN  5766.00
# 3  <a refstr=STASSUN_ET_AL__2019 href=https://ui....         NaN  4616.52
# 4  <a refstr=MAYO_ET_AL__2018 href=https://ui.ads...         NaN  4720.00
#
#    st_tefferr1  st_tefferr2  st_tefflim    st_rad  st_raderr1  st_raderr2  \
# 0        50.00       -50.00         0.0  0.956122    0.098585   -0.054675
# 1        99.00       -99.00         0.0  0.928000    0.055000   -0.040000
# 2        99.00       -99.00         0.0  1.080000    0.060000   -0.060000
# 3        82.36      -115.56         0.0  0.762602    0.053651   -0.037585
# 4        50.00       -50.00         0.0  0.710995    0.018609   -0.020398
#
#    st_radlim   st_mass  st_masserr1  st_masserr2  st_masslim  st_met  \
# 0        0.0  0.963861     0.029568    -0.032166         0.0   -0.06
# 1        0.0  0.961000     0.032000    -0.029000         0.0   -0.15
# 2        0.0  1.670000     0.400000    -0.400000         0.0   -0.15
# 3        0.0  0.730000     0.084105    -0.081044         0.0   -0.03
# 4        0.0       NaN          NaN          NaN         NaN   -0.06
#
#    st_meterr1  st_meterr2  st_metlim st_metratio  st_logg  st_loggerr1  \
# 0       0.080      -0.080        0.0      [Fe/H]  4.38000     0.100000
# 1       0.050      -0.050        0.0      [Fe/H]  4.50000     0.080000
# 2         NaN         NaN        0.0      [Fe/H]  4.50000     0.080000
# 3       0.034      -0.034        0.0       [M/H]  4.53679     0.075486
# 4       0.080      -0.080        0.0      [Fe/H]  4.50000     0.100000
#
#    st_loggerr2  st_logglim                                         sy_refname  \
# 0    -0.100000         0.0  <a refstr=STASSUN_ET_AL__2019 href=https://ui....
# 1    -0.080000         0.0  <a refstr=STASSUN_ET_AL__2019 href=https://ui....
# 2    -0.080000         0.0  <a refstr=STASSUN_ET_AL__2019 href=https://ui....
# 3    -0.090593         0.0  <a refstr=STASSUN_ET_AL__2019 href=https://ui....
# 4    -0.100000         0.0  <a refstr=STASSUN_ET_AL__2019 href=https://ui....
#
#           rastr          ra         decstr        dec   sy_dist  sy_disterr1  \
# 0  03h34m36.27s   53.651123  +20d35m56.47s  20.599021  179.4610       1.2570
# 1  03h34m36.27s   53.651123  +20d35m56.47s  20.599021  179.4610       1.2570
# 2  03h34m36.27s   53.651123  +20d35m56.47s  20.599021  179.4610       1.2570
# 3  12h15m23.10s  183.846245  -06d16m05.98s  -6.268329   97.1795       0.4642
# 4  12h15m23.10s  183.846245  -06d16m05.98s  -6.268329   97.1795       0.4642
#
#    sy_disterr2  sy_vmag  sy_vmagerr1  sy_vmagerr2  sy_kmag  sy_kmagerr1  \
# 0      -1.2400   10.849        0.012       -0.012    9.368        0.018
# 1      -1.2400   10.849        0.012       -0.012    9.368        0.018
# 2      -1.2400   10.849        0.012       -0.012    9.368        0.018
# 3      -0.4598   11.727        0.046       -0.046    9.220        0.019
# 4      -0.4598   11.727        0.046       -0.046    9.220        0.019
#
#    sy_kmagerr2  sy_gaiamag  sy_gaiamagerr1  sy_gaiamagerr2   rowupdate  \
# 0       -0.018     10.8644        0.000249       -0.000249  2018-04-25
# 1       -0.018     10.8644        0.000249       -0.000249  2018-04-25
# 2       -0.018     10.8644        0.000249       -0.000249  2018-04-25
# 3       -0.019     11.3995        0.001307       -0.001307  2018-08-02
# 4       -0.019     11.3995        0.001307       -0.001307  2018-02-15
#
#   pl_pubdate releasedate
# 0    2018-03  2018-02-15
# 1    2016-10  2016-07-28
# 2    2017-03  2018-04-26
# 3    2018-08  2018-08-02
# 4    2018-03  2018-02-15

# %%
df.drop(['loc_rowid','pl_name','hostname','disp_refname','disc_year',
'pl_refname','st_refname','sy_refname','rastr','decstr','rowupdate','pl_pubdate','releasedate'],axis=1,inplace=True)
df = df.loc[:, df.notnull().sum() >= 1000]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3982 entries, 0 to 4003
# Data columns (total 56 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   default_flag     3982 non-null   int64
#  1   disposition      3982 non-null   object
#  2   sy_snum          3982 non-null   int64
#  3   sy_pnum          3982 non-null   int64
#  4   discoverymethod  3982 non-null   object
#  5   disc_facility    3982 non-null   object
#  6   soltype          3982 non-null   object
#  7   pl_controv_flag  3982 non-null   int64
#  8   pl_orbper        3938 non-null   float64
#  9   pl_orbpererr1    3054 non-null   float64
#  10  pl_orbpererr2    3054 non-null   float64
#  11  pl_orbperlim     3938 non-null   float64
#  12  pl_rade          3155 non-null   float64
#  13  pl_radeerr1      2872 non-null   float64
#  14  pl_radeerr2      2872 non-null   float64
#  15  pl_radelim       3155 non-null   float64
#  16  pl_radj          3155 non-null   float64
#  17  pl_radjerr1      2872 non-null   float64
#  18  pl_radjerr2      2872 non-null   float64
#  19  pl_radjlim       3155 non-null   float64
#  20  ttv_flag         3982 non-null   int64
#  21  st_teff          2879 non-null   float64
#  22  st_tefferr1      2574 non-null   float64
#  23  st_tefferr2      2568 non-null   float64
#  24  st_tefflim       2879 non-null   float64
#  25  st_rad           3858 non-null   float64
#  26  st_raderr1       3231 non-null   float64
#  27  st_raderr2       3225 non-null   float64
#  28  st_radlim        3858 non-null   float64
#  29  st_mass          2095 non-null   float64
#  30  st_masserr1      1941 non-null   float64
#  31  st_masserr2      1935 non-null   float64
#  32  st_masslim       2095 non-null   float64
#  33  st_met           1692 non-null   float64
#  34  st_meterr1       1661 non-null   float64
#  35  st_meterr2       1661 non-null   float64
#  36  st_metlim        1692 non-null   float64
#  37  st_metratio      1689 non-null   object
#  38  st_logg          2346 non-null   float64
#  39  st_loggerr1      2135 non-null   float64
#  40  st_loggerr2      2135 non-null   float64
#  41  st_logglim       2346 non-null   float64
#  42  ra               3982 non-null   float64
#  43  dec              3982 non-null   float64
#  44  sy_dist          3857 non-null   float64
#  45  sy_disterr1      3726 non-null   float64
#  46  sy_disterr2      3726 non-null   float64
#  47  sy_vmag          3940 non-null   float64
#  48  sy_vmagerr1      3940 non-null   float64
#  49  sy_vmagerr2      3940 non-null   float64
#  50  sy_kmag          3959 non-null   float64
#  51  sy_kmagerr1      3951 non-null   float64
#  52  sy_kmagerr2      3951 non-null   float64
#  53  sy_gaiamag       3926 non-null   float64
#  54  sy_gaiamagerr1   3926 non-null   float64
#  55  sy_gaiamagerr2   3926 non-null   float64
# dtypes: float64(46), int64(5), object(5)
# memory usage: 1.7+ MB

# %%
print(df['discoverymethod'].unique())
print(df['soltype'].unique())
print(df['st_metratio'].unique())
print(df['disc_facility'].unique())
print(df['disposition'].unique())
# Out:
# ['Transit' 'Radial Velocity' 'Microlensing']
# ['Published Confirmed' 'Published Candidate' 'TESS Project Candidate']
# ['[Fe/H]' '[M/H]' nan '[m/H]']
# ['K2' 'HATNet' 'HATSouth' 'Multiple Observatories'
#  'Roque de los Muchachos Observatory'
#  'CHaracterising ExOPlanets Satellite (CHEOPS)' 'La Silla Observatory'
#  'Qatar' 'SuperWASP-South' 'SuperWASP']
# ['CONFIRMED' 'CANDIDATE' 'FALSE POSITIVE']

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# Aplicar no label
df["label"] = encoder.fit_transform(df["disposition"])
df["discoverymethod_encoded"] = encoder.fit_transform(df["discoverymethod"])
df["soltype_encoded"] = encoder.fit_transform(df["soltype"])
df["disc_facility_encoded"] = encoder.fit_transform(df["disc_facility"])

# Fill NaN with placeholder
df["st_metratio"] = df["st_metratio"].fillna("missing")
df["st_metratio_encoded"] = encoder.fit_transform(df["st_metratio"])


df.drop(['st_metratio','disposition','discoverymethod','soltype','disc_facility'],axis=1,inplace=True)
df.head()
# Out:
#    default_flag  sy_snum  sy_pnum  pl_controv_flag  pl_orbper  pl_orbpererr1  \
# 0             0        1        1                0  41.688644       0.003353
# 1             0        1        1                0  41.685500       0.003000
# 2             1        1        1                0  41.685500       0.003000
# 3             1        1        0                0   2.301830       0.000280
# 4             0        1        0                0   2.302368       0.000105
#
#    pl_orbpererr2  pl_orbperlim   pl_rade  pl_radeerr1  pl_radeerr2  \
# 0      -0.003419           0.0  2.355454     0.310000    -0.166773
# 1      -0.003100           0.0  2.230000     0.140000    -0.110000
# 2      -0.003000           0.0  2.578070     0.112090    -0.112090
# 3      -0.000300           0.0  1.120000     0.110000    -0.080000
# 4      -0.000103           0.0  1.312588     0.524177    -0.120814
#
#    pl_radelim   pl_radj  pl_radjerr1  pl_radjerr2  pl_radjlim  ttv_flag  \
# 0         0.0  0.210139     0.027656    -0.014878         0.0         0
# 1         0.0  0.198947     0.012490    -0.009814         0.0         0
# 2         0.0  0.230000     0.010000    -0.010000         0.0         0
# 3         0.0  0.099900     0.009800    -0.007000         0.0         0
# 4         0.0  0.120000     0.050000    -0.010000         0.0         0
#
#    st_teff  st_tefferr1  st_tefferr2  st_tefflim    st_rad  st_raderr1  \
# 0  5703.00        50.00       -50.00         0.0  0.956122    0.098585
# 1  5766.00        99.00       -99.00         0.0  0.928000    0.055000
# 2  5766.00        99.00       -99.00         0.0  1.080000    0.060000
# 3  4616.52        82.36      -115.56         0.0  0.762602    0.053651
# 4  4720.00        50.00       -50.00         0.0  0.710995    0.018609
#
#    st_raderr2  st_radlim   st_mass  st_masserr1  st_masserr2  st_masslim  \
# 0   -0.054675        0.0  0.963861     0.029568    -0.032166         0.0
# 1   -0.040000        0.0  0.961000     0.032000    -0.029000         0.0
# 2   -0.060000        0.0  1.670000     0.400000    -0.400000         0.0
# 3   -0.037585        0.0  0.730000     0.084105    -0.081044         0.0
# 4   -0.020398        0.0       NaN          NaN          NaN         NaN
#
#    st_met  st_meterr1  st_meterr2  st_metlim  st_logg  st_loggerr1  \
# 0   -0.06       0.080      -0.080        0.0  4.38000     0.100000
# 1   -0.15       0.050      -0.050        0.0  4.50000     0.080000
# 2   -0.15         NaN         NaN        0.0  4.50000     0.080000
# 3   -0.03       0.034      -0.034        0.0  4.53679     0.075486
# 4   -0.06       0.080      -0.080        0.0  4.50000     0.100000
#
#    st_loggerr2  st_logglim          ra        dec   sy_dist  sy_disterr1  \
# 0    -0.100000         0.0   53.651123  20.599021  179.4610       1.2570
# 1    -0.080000         0.0   53.651123  20.599021  179.4610       1.2570
# 2    -0.080000         0.0   53.651123  20.599021  179.4610       1.2570
# 3    -0.090593         0.0  183.846245  -6.268329   97.1795       0.4642
# 4    -0.100000         0.0  183.846245  -6.268329   97.1795       0.4642
#
#    sy_disterr2  sy_vmag  sy_vmagerr1  sy_vmagerr2  sy_kmag  sy_kmagerr1  \
# 0      -1.2400   10.849        0.012       -0.012    9.368        0.018
# 1      -1.2400   10.849        0.012       -0.012    9.368        0.018
# 2      -1.2400   10.849        0.012       -0.012    9.368        0.018
# 3      -0.4598   11.727        0.046       -0.046    9.220        0.019
# 4      -0.4598   11.727        0.046       -0.046    9.220        0.019
#
#    sy_kmagerr2  sy_gaiamag  sy_gaiamagerr1  sy_gaiamagerr2  label  \
# 0       -0.018     10.8644        0.000249       -0.000249      1
# 1       -0.018     10.8644        0.000249       -0.000249      1
# 2       -0.018     10.8644        0.000249       -0.000249      1
# 3       -0.019     11.3995        0.001307       -0.001307      0
# 4       -0.019     11.3995        0.001307       -0.001307      0
#
#    discoverymethod_encoded  soltype_encoded  disc_facility_encoded  \
# 0                        2                1                      3
# 1                        2                1                      3
# 2                        2                1                      3
# 3                        2                0                      3
# 4                        2                0                      3
#
#    st_metratio_encoded
# 0                    0
# 1                    0
# 2                    0
# 3                    1
# 4                    0

# %%
for col in ["discoverymethod_encoded", "disc_facility_encoded", "soltype_encoded"]:
    if df[col].isnull().any():
        df.fillna({col: df[col].mode()[0]}, inplace=True)
df = df.fillna(df.mean())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3982 entries, 0 to 4003
# Data columns (total 56 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   default_flag             3982 non-null   int64
#  1   sy_snum                  3982 non-null   int64
#  2   sy_pnum                  3982 non-null   int64
#  3   pl_controv_flag          3982 non-null   int64
#  4   pl_orbper                3982 non-null   float64
#  5   pl_orbpererr1            3982 non-null   float64
#  6   pl_orbpererr2            3982 non-null   float64
#  7   pl_orbperlim             3982 non-null   float64
#  8   pl_rade                  3982 non-null   float64
#  9   pl_radeerr1              3982 non-null   float64
#  10  pl_radeerr2              3982 non-null   float64
#  11  pl_radelim               3982 non-null   float64
#  12  pl_radj                  3982 non-null   float64
#  13  pl_radjerr1              3982 non-null   float64
#  14  pl_radjerr2              3982 non-null   float64
#  15  pl_radjlim               3982 non-null   float64
#  16  ttv_flag                 3982 non-null   int64
#  17  st_teff                  3982 non-null   float64
#  18  st_tefferr1              3982 non-null   float64
#  19  st_tefferr2              3982 non-null   float64
#  20  st_tefflim               3982 non-null   float64
#  21  st_rad                   3982 non-null   float64
#  22  st_raderr1               3982 non-null   float64
#  23  st_raderr2               3982 non-null   float64
#  24  st_radlim                3982 non-null   float64
#  25  st_mass                  3982 non-null   float64
#  26  st_masserr1              3982 non-null   float64
#  27  st_masserr2              3982 non-null   float64
#  28  st_masslim               3982 non-null   float64
#  29  st_met                   3982 non-null   float64
#  30  st_meterr1               3982 non-null   float64
#  31  st_meterr2               3982 non-null   float64
#  32  st_metlim                3982 non-null   float64
#  33  st_logg                  3982 non-null   float64
#  34  st_loggerr1              3982 non-null   float64
#  35  st_loggerr2              3982 non-null   float64
#  36  st_logglim               3982 non-null   float64
#  37  ra                       3982 non-null   float64
#  38  dec                      3982 non-null   float64
#  39  sy_dist                  3982 non-null   float64
#  40  sy_disterr1              3982 non-null   float64
#  41  sy_disterr2              3982 non-null   float64
#  42  sy_vmag                  3982 non-null   float64
#  43  sy_vmagerr1              3982 non-null   float64
#  44  sy_vmagerr2              3982 non-null   float64
#  45  sy_kmag                  3982 non-null   float64
#  46  sy_kmagerr1              3982 non-null   float64
#  47  sy_kmagerr2              3982 non-null   float64
#  48  sy_gaiamag               3982 non-null   float64
#  49  sy_gaiamagerr1           3982 non-null   float64
#  50  sy_gaiamagerr2           3982 non-null   float64
#  51  label                    3982 non-null   int64
#  52  discoverymethod_encoded  3982 non-null   int64
#  53  soltype_encoded          3982 non-null   int64
#  54  disc_facility_encoded    3982 non-null   int64
#  55  st_metratio_encoded      3982 non-null   int64
# dtypes: float64(46), int64(10)
# memory usage: 1.7 MB

# %%
for col in ["discoverymethod_encoded", "disc_facility_encoded", "soltype_encoded"]:
    if df[col].isnull().any():
        df.fillna({col: df[col].mode()[0]}, inplace=True)
df = df.fillna(df.mean())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3982 entries, 0 to 4003
# Data columns (total 56 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   default_flag             3982 non-null   int64
#  1   sy_snum                  3982 non-null   int64
#  2   sy_pnum                  3982 non-null   int64
#  3   pl_controv_flag          3982 non-null   int64
#  4   pl_orbper                3982 non-null   float64
#  5   pl_orbpererr1            3982 non-null   float64
#  6   pl_orbpererr2            3982 non-null   float64
#  7   pl_orbperlim             3982 non-null   float64
#  8   pl_rade                  3982 non-null   float64
#  9   pl_radeerr1              3982 non-null   float64
#  10  pl_radeerr2              3982 non-null   float64
#  11  pl_radelim               3982 non-null   float64
#  12  pl_radj                  3982 non-null   float64
#  13  pl_radjerr1              3982 non-null   float64
#  14  pl_radjerr2              3982 non-null   float64
#  15  pl_radjlim               3982 non-null   float64
#  16  ttv_flag                 3982 non-null   int64
#  17  st_teff                  3982 non-null   float64
#  18  st_tefferr1              3982 non-null   float64
#  19  st_tefferr2              3982 non-null   float64
#  20  st_tefflim               3982 non-null   float64
#  21  st_rad                   3982 non-null   float64
#  22  st_raderr1               3982 non-null   float64
#  23  st_raderr2               3982 non-null   float64
#  24  st_radlim                3982 non-null   float64
#  25  st_mass                  3982 non-null   float64
#  26  st_masserr1              3982 non-null   float64
#  27  st_masserr2              3982 non-null   float64
#  28  st_masslim               3982 non-null   float64
#  29  st_met                   3982 non-null   float64
#  30  st_meterr1               3982 non-null   float64
#  31  st_meterr2               3982 non-null   float64
#  32  st_metlim                3982 non-null   float64
#  33  st_logg                  3982 non-null   float64
#  34  st_loggerr1              3982 non-null   float64
#  35  st_loggerr2              3982 non-null   float64
#  36  st_logglim               3982 non-null   float64
#  37  ra                       3982 non-null   float64
#  38  dec                      3982 non-null   float64
#  39  sy_dist                  3982 non-null   float64
#  40  sy_disterr1              3982 non-null   float64
#  41  sy_disterr2              3982 non-null   float64
#  42  sy_vmag                  3982 non-null   float64
#  43  sy_vmagerr1              3982 non-null   float64
#  44  sy_vmagerr2              3982 non-null   float64
#  45  sy_kmag                  3982 non-null   float64
#  46  sy_kmagerr1              3982 non-null   float64
#  47  sy_kmagerr2              3982 non-null   float64
#  48  sy_gaiamag               3982 non-null   float64
#  49  sy_gaiamagerr1           3982 non-null   float64
#  50  sy_gaiamagerr2           3982 non-null   float64
#  51  label                    3982 non-null   int64
#  52  discoverymethod_encoded  3982 non-null   int64
#  53  soltype_encoded          3982 non-null   int64
#  54  disc_facility_encoded    3982 non-null   int64
#  55  st_metratio_encoded      3982 non-null   int64
# dtypes: float64(46), int64(10)
# memory usage: 1.7 MB

# %%
df_final = df
df_final = df[ [
        'label',
        'sy_snum',
        'sy_pnum',
        'discoverymethod_encoded',
        'disc_facility_encoded',
        'soltype_encoded',
        'pl_controv_flag',
        'pl_orbper',
        'ttv_flag',
        'st_rad',
        'sy_dist',
        'sy_vmag',
        'sy_kmag',
        'sy_gaiamag'
]]
df_final.head()
# Out:
#    label  sy_snum  sy_pnum  discoverymethod_encoded  disc_facility_encoded  \
# 0      1        1        1                        2                      3
# 1      1        1        1                        2                      3
# 2      1        1        1                        2                      3
# 3      0        1        0                        2                      3
# 4      0        1        0                        2                      3
#
#    soltype_encoded  pl_controv_flag  pl_orbper  ttv_flag    st_rad   sy_dist  \
# 0                1                0  41.688644         0  0.956122  179.4610
# 1                1                0  41.685500         0  0.928000  179.4610
# 2                1                0  41.685500         0  1.080000  179.4610
# 3                0                0   2.301830         0  0.762602   97.1795
# 4                0                0   2.302368         0  0.710995   97.1795
#
#    sy_vmag  sy_kmag  sy_gaiamag
# 0   10.849    9.368     10.8644
# 1   10.849    9.368     10.8644
# 2   10.849    9.368     10.8644
# 3   11.727    9.220     11.3995
# 4   11.727    9.220     11.3995

# %%
list(df_final.columns)
# Out:
# ['label',
#  'sy_snum',
#  'sy_pnum',
#  'discoverymethod_encoded',
#  'disc_facility_encoded',
#  'soltype_encoded',
#  'pl_controv_flag',
#  'pl_orbper',
#  'ttv_flag',
#  'st_rad',
#  'sy_dist',
#  'sy_vmag',
#  'sy_kmag',
#  'sy_gaiamag']

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score, classification_report
import xgboost as xgb
import joblib
from time import time

start = time()

# ==============================
# SPLITS E MODELO BASE
# ==============================

# Features e label
X = df_final.drop(['label'], axis=1)
y = df_final['label']

# Primeiro split: 70% treino, 30% restante
X_train_full, X_temp, y_train_full, y_temp = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42
)

# Segundo split: 20% teste, 10% blind validation
X_test, X_blind, y_test, y_blind = train_test_split(
    X_temp, y_temp, test_size=0.3333, stratify=y_temp, random_state=42
)

print(f"Train shape: {X_train_full.shape}")
print(f"Test shape: {X_test.shape}")
print(f"Blind validation shape: {X_blind.shape}")

# ==============================
# CROSS-VALIDATION
# ==============================

n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
fold_results = []

for fold, (train_idx, val_idx) in enumerate(skf.split(X_train_full, y_train_full), 1):
    print(f"\nFold {fold}")
    X_train, X_val = X_train_full.iloc[train_idx], X_train_full.iloc[val_idx]
    y_train, y_val = y_train_full.iloc[train_idx], y_train_full.iloc[val_idx]

    model = xgb.XGBClassifier(eval_metric='mlogloss', objective='multi:softprob')
    model.fit(X_train.values, y_train.values)

    y_pred_val = model.predict(X_val.values)
    acc = accuracy_score(y_val, y_pred_val)
    f1 = f1_score(y_val, y_pred_val, average='weighted')
    print(f"Validation Accuracy: {acc:.4f} | F1-score: {f1:.4f}")
    fold_results.append({'fold': fold, 'accuracy': acc, 'f1': f1})

acc_mean = np.mean([r['accuracy'] for r in fold_results])
f1_mean = np.mean([r['f1'] for r in fold_results])
print(f"\nMédia Validation Accuracy: {acc_mean:.4f}")
print(f"Média Validation F1-score: {f1_mean:.4f}")

# ==============================
# MODELO FINAL COMPLETO
# ==============================

final_model = xgb.XGBClassifier(eval_metric='mlogloss', objective='multi:softprob')
final_model.fit(X_train_full.values, y_train_full.values)

feat_imp = pd.Series(final_model.feature_importances_, index=X_train_full.columns).sort_values(ascending=False)
feat_imp.to_csv('summary/K2_light_all_feature_importance.csv')
print("\nTop 10 Feature importances:")
print(feat_imp.head(10))

# Avaliação no teste
y_pred_test = final_model.predict(X_test.values)
print("\n--- Base Model Test Results ---")
print(f"Accuracy: {accuracy_score(y_test, y_pred_test):.4f}")
print(f"F1-score: {f1_score(y_test, y_pred_test, average='weighted'):.4f}")

# Avaliação na blind validation
y_pred_blind = final_model.predict(X_blind.values)
print("\n--- Base Model Blind Results ---")
print(f"Accuracy: {accuracy_score(y_blind, y_pred_blind):.4f}")
print(f"F1-score: {f1_score(y_blind, y_pred_blind, average='weighted'):.4f}")

#joblib.dump(final_model, 'xgb_final_model.pkl')
#final_model.save_model('xgb_final_model.model')

# ==============================
# TESTES COM 90%, 95%, 99% DAS FEATURES
# ==============================

thresholds = [0.90, 0.95, 0.99]
results_summary = []
feat_imp_cumsum = feat_imp.cumsum()

for th in thresholds:
    # Seleciona features até atingir o threshold cumulativo
    idx = np.searchsorted(feat_imp_cumsum.values, th, side='right')
    selected_features = feat_imp_cumsum.index[:idx+1].tolist()
    print(th,selected_features)

    print(f"\n===== Testing with top {th*100:.0f}% feature importance =====")
    print(f"Selected features: {len(selected_features)}")

    X_train_sel = X_train_full[selected_features]
    X_test_sel = X_test[selected_features]
    X_blind_sel = X_blind[selected_features]

    model_sel = xgb.XGBClassifier(eval_metric='mlogloss', objective='multi:softprob')
    model_sel.fit(X_train_sel.values, y_train_full.values)

    # Test set
    y_pred_test_sel = model_sel.predict(X_test_sel.values)
    acc_test = accuracy_score(y_test, y_pred_test_sel)
    f1_test = f1_score(y_test, y_pred_test_sel, average='weighted')

    # Blind set
    y_pred_blind_sel = model_sel.predict(X_blind_sel.values)
    acc_blind = accuracy_score(y_blind, y_pred_blind_sel)
    f1_blind = f1_score(y_blind, y_pred_blind_sel, average='weighted')

    print(f"Test Accuracy: {acc_test:.4f} | F1: {f1_test:.4f}")
    print(f"Blind Accuracy: {acc_blind:.4f} | F1: {f1_blind:.4f}")
    report_test = classification_report(y_test, y_pred_test_sel)
    report_blind = classification_report(y_blind, y_pred_blind_sel)
    print(f"\n Number of Features for this model: {X_test_sel.shape[1]}")
    print(f"\n📊 Classification Test Report: K2 Light Model with {th*100:.0f}% feature importance\n", report_test)
    print(f"\n📊 Classification Blind Report: K2 Light Model with {th*100:.0f}% feature importance\n", report_blind)

    results_summary.append({
        'Threshold': f'{int(th*100)}%',
        'N_Features': len(selected_features),
        'Test_Accuracy': acc_test,
        'Test_F1': f1_test,
        'Blind_Accuracy': acc_blind,
        'Blind_F1': f1_blind
    })

    # Salvar modelo em PKL e .model
    #joblib.dump(model_sel, f'xgb_model_{int(th*100)}perc_features.pkl')
    model_sel.save_model(f'models/K2_model_light_{int(th*100)}perc_features.model')

# ==============================
# SUMÁRIO FINAL
# ==============================

results_df = pd.DataFrame(results_summary)
print("\n=== Summary of Reduced Feature Tests ===")
display(results_df)
results_df.to_csv("summary/K2_light_feature_importance_summary.csv", index=False)

end = time()
print(f"\nTotal runtime: {end - start:.2f} seconds")
# Out:
# Train shape: (2787, 13)
# Test shape: (796, 13)
# Blind validation shape: (399, 13)
#
# Fold 1
# Validation Accuracy: 0.9247 | F1-score: 0.9177
#
# Fold 2
# Validation Accuracy: 0.9265 | F1-score: 0.9158
#
# Fold 3
# Validation Accuracy: 0.9390 | F1-score: 0.9324
#
# Fold 4
# Validation Accuracy: 0.9425 | F1-score: 0.9394
#
# Fold 5
# Validation Accuracy: 0.9372 | F1-score: 0.9314
#
# Média Validation Accuracy: 0.9340
# Média Validation F1-score: 0.9273
#
# Top 10 Feature importances:
# sy_pnum                    0.908264
# soltype_encoded            0.028804
# pl_orbper                  0.011572
# sy_vmag                    0.011483
# sy_kmag                    0.010977
# sy_gaiamag                 0.009865
# st_rad                     0.009592
# sy_dist                    0.009444
# sy_snum                    0.000000
# discoverymethod_encoded    0.000000
# dtype: float32
#
# --- Base Model Test Results ---
# Accuracy: 0.9435
# F1-score: 0.9391
#
# --- Base Model Blind Results ---
# Accuracy: 0.9373
# F1-score: 0.9335
# 0.9 ['sy_pnum']
#
# ===== Testing with top 90% feature importance =====
# Selected features: 1
# Test Accuracy: 0.9171 | F1: 0.8837
# Blind Accuracy: 0.9148 | F1: 0.8819
#
#  Number of Features for this model: 1
#
# 📊 Classification Test Report: K2 Light Model with 90% feature importance
#                precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89       274
#            1       0.99      1.00      0.99       463
#            2       0.00      0.00      0.00        59
#
#     accuracy                           0.92       796
#    macro avg       0.60      0.66      0.63       796
# weighted avg       0.85      0.92      0.88       796
#
#
# 📊 Classification Blind Report: K2 Light Model with 90% feature importance
#                precision    recall  f1-score   support
#
#            0       0.82      0.96      0.89       138
#            1       0.98      1.00      0.99       232
#            2       0.00      0.00      0.00        29
#
#     accuracy                           0.91       399
#    macro avg       0.60      0.65      0.63       399
# weighted avg       0.85      0.91      0.88       399
#
# 0.95 ['sy_pnum', 'soltype_encoded', 'pl_orbper', 'sy_vmag']
#
# ===== Testing with top 95% feature importance =====
# Selected features: 4
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/lib/python3.10/site-packages/xgboost/sklearn.py:1028: UserWarning: [01:39:57] WARNING: /workspace/src/c_api/c_api.cc:1427: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   self.get_booster().save_model(fname)
# Test Accuracy: 0.9347 | F1: 0.9322
# Blind Accuracy: 0.9398 | F1: 0.9352
#
#  Number of Features for this model: 4
#
# 📊 Classification Test Report: K2 Light Model with 95% feature importance
#                precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91       274
#            1       0.99      1.00      1.00       463
#            2       0.61      0.51      0.56        59
#
#     accuracy                           0.93       796
#    macro avg       0.83      0.81      0.82       796
# weighted avg       0.93      0.93      0.93       796
#
#
# 📊 Classification Blind Report: K2 Light Model with 95% feature importance
#                precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       138
#            1       1.00      1.00      1.00       232
#            2       0.68      0.45      0.54        29
#
#     accuracy                           0.94       399
#    macro avg       0.86      0.80      0.82       399
# weighted avg       0.93      0.94      0.94       399
#
# 0.99 ['sy_pnum', 'soltype_encoded', 'pl_orbper', 'sy_vmag', 'sy_kmag', 'sy_gaiamag', 'st_rad']
#
# ===== Testing with top 99% feature importance =====
# Selected features: 7
# /opt/conda/lib/python3.10/site-packages/xgboost/sklearn.py:1028: UserWarning: [01:39:58] WARNING: /workspace/src/c_api/c_api.cc:1427: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   self.get_booster().save_model(fname)
# Test Accuracy: 0.9447 | F1: 0.9397
# Blind Accuracy: 0.9348 | F1: 0.9323
#
#  Number of Features for this model: 7
#
# 📊 Classification Test Report: K2 Light Model with 99% feature importance
#                precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       274
#            1       0.99      1.00      0.99       463
#            2       0.78      0.47      0.59        59
#
#     accuracy                           0.94       796
#    macro avg       0.89      0.81      0.84       796
# weighted avg       0.94      0.94      0.94       796
#
#
# 📊 Classification Blind Report: K2 Light Model with 99% feature importance
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91       138
#            1       0.99      0.99      0.99       232
#            2       0.65      0.52      0.58        29
#
#     accuracy                           0.93       399
#    macro avg       0.84      0.81      0.83       399
# weighted avg       0.93      0.93      0.93       399
#
#
# === Summary of Reduced Feature Tests ===
# /opt/conda/lib/python3.10/site-packages/xgboost/sklearn.py:1028: UserWarning: [01:39:58] WARNING: /workspace/src/c_api/c_api.cc:1427: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   self.get_booster().save_model(fname)
#   Threshold  N_Features  Test_Accuracy   Test_F1  Blind_Accuracy  Blind_F1
# 0       90%           1       0.917085  0.883651        0.914787  0.881921
# 1       95%           4       0.934673  0.932246        0.939850  0.935158
# 2       99%           7       0.944724  0.939688        0.934837  0.932349
# Total runtime: 2.54 seconds
